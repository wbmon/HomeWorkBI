# %% [markdown]
# ### Задание 1 .
# **Скачайте Power BI Desktop - в качестве подтверждения присылайте скрин интерфейса.**

# %% [markdown]
# ![](PBIDesktop.jpg "Downloaded Power BI Desktop")

# %% [markdown]
# ### Задание 2.
# **Распишите подробнее свой путь в аналитике и ожидания от обучения:
# Есть ли у вас опыт в аналитике и сколько лет?
# В каком направлении анализа планируете развиваться: BI, бизнес, финансовый, маркетинговый, HR, системный, продуктовая?
# Возможно вы руководитель или владелец бизнеса, тогда распишите как поможет аналитика в ваших задачах.
# Какие основные навыки вы хотите освоить?
# Есть ли у вас уже опыт работы в какой-то BI-системе и если да, то какой?**

# %% [markdown]
# Мне 50 лет и вся моя почти 30-летняя профессиональная деятельность связана с преподаванием информатики в школе. На курсы пришел, чтобы оставаться в тренде современных IT.
# В начале 2000-х работал директором школы и начальником управления образования города, поэтому в аналитике опыт есть, но тогда основным инструментом был Excel.
# Не думаю, что буду связывать дальнейшую свою деятельность с аналитикой. Поэтому не ожидаю от курса ничего, кроме знакомства с новыми инструментами.
